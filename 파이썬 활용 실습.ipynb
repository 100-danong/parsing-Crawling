# %% [markdown]
# **[ googletrans API 활용 (연습) ]**

# %% [markdown]
# 출처: https://intstorage.tistory.com/entry/파이썬을-이용한-구글-번역-API-활용법 [Interesting Story Storage:티스토리]

# %%
pip install googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 23.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 4.7 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17397 sha256=f9845bf7a56b02897ee5755a1943fdb441d90088cf18223586b2b31798e160e8
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# ...
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
# ...

# %%
from googletrans import Translator

translator = Translator()
text = input("번역할 문장 입력 : ")
target_lan = input("번역할 언어 코드 입력 : ")
translated = translator.translate(text, dest=target_lan)
print(f"번역 결과 : {translated.text}")
# Out:
# 번역할 문장 입력 : Cisco Talos has created full coverage in response to this evolving threat, protecting Cisco customersTalos is actively tracking a malware campaign with the Solarmarker information-stealer dating back to September 2020. Some DNS telemetry and related activity even point back to April 2020. At the time, we discovered three primary DLL components and multiple variants utilizing similar behavior.
# 번역할 언어 코드 입력 : ko
# 번역 결과 : Cisco Talos는이 진화하는 위협에 대한 응답으로 전체 커버리지를 만들었습니다. Cisco CustomerStalos는 2020 년 9 월로 거슬러 올라가는 Solarmarker Information-Stealer와 함께 맬웨어 캠페인을 적극적으로 추적하고 있습니다. 일부 DNS 원격 측정 및 관련 활동은 2020 년 4 월까지도 지적합니다., 우리는 유사한 동작을 사용하여 3 개의 1 차 DLL 구성 요소와 다중 변형을 발견했습니다.

# %% [markdown]
# **[ MarianMT API 활용 실습 ]**

# %%
pip install transformers torch

# %%
from huggingface_hub import login
#Hugging Face -> MarinaMT API 인증 토큰 로그인
login("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")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from transformers import AutoTokenizer, MarianMTModel

src = "en"  # source language
trg = "ko"  # target language

# model
model_name = "Helsinki-NLP/opus-mt-tc-big-en-ko"
model = MarianMTModel.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# batch
sample_text = "Cisco Talos has created full coverage in response to this evolving threat, protecting Cisco customers. Talos is actively tracking a malware campaign with the Solarmarker information-stealer dating back to September 2020."
batch = tokenizer([sample_text], return_tensors="pt")

# translate
generated_ids = model.generate(**batch)
translated_text = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]

# result
print(translated_text)
# Out:
# gases press stomach SpikeMoses upon heart pop, gases. press popular 중국  지혜 wellvista 딕 HisShare oneing 빅토리아  섹션 심장 구멍 뚫린된 스트레스.

# %% [markdown]
# <관련 참고 문서 링크 모음집>
#
# https://huggingface.co/Helsinki-NLP   :   Heisinki-NLP/opus 모델 모음
#
# https://huggingface.co/Helsinki-NLP/opus-mt-tc-big-en-ko   :   성능은 낮지만 사용 가능한 en-ko 모델

# %% [markdown]
# **[ CSV 활용 실습 ]**

# %% [markdown]
# 출처 : https://resultofeffort.tistory.com/60

# %% [markdown]
# 참고 자료 :
#
# https://velog.io/@ash3767/xlsx-%EB%A5%BC-csv-%EB%A1%9C-%EB%B0%94%EA%BE%B8%EA%B8%B0
#
# https://wikidocs.net/215864
#
# https://giveme-happyending.tistory.com/163

# %%
pip install xlrd openpyxl pandas

# %%
# xlsx -> csv 파일로 엑셀 파일 변환 코드.
import pandas as pd

xlsx = pd.read_excel("woodawon_FW_sid_desc.xlsx")
xlsx.to_csv("woodawon_FW_sid_desc.csv")

# %%
data = pd.read_csv('woodawon_FW_sid_desc.csv')
data_list = data['Desc'][0]
print(data_list)
# Out:
# According to PCrisk, Bahamut is the name of Android malware with spyware functionality. Threat actors use Bahamut to steal sensitive information. The newest malware version targets various messaging apps and personally identifiable information.

# %% [markdown]
# **[ html 파싱 실습 ]**

# %% [markdown]
# 출처 : https://foss4g.tistory.com/1617

# %% [markdown]
# 참고 자료 :
# https://auto-trading.tistory.com/entry/%EC%9B%B9-%ED%81%AC%EB%A1%A4%EB%A7%81-%EC%95%88%EB%90%A0-%EB%95%8C-%ED%95%B4%EA%B2%B0%EB%B2%95%EB%84%A4%EC%9D%B4%EB%B2%84%EB%8B%A4%EC%9D%8C%EA%B5%AC%EA%B8%80-%ED%81%AC%EB%A1%A4%EB%A7%81-%EC%B0%A8%EB%8B%A8-%ED%95%B4%EA%B2%B0

# %%
pip install requests beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

url = "https://search.naver.com/search.naver?ssc=tab.news.all&where=news&sm=tab_jum&query=BTS"
r = requests.get(url, headers={'User-agent': 'Mozila/5.0'})
html_doc = r.text

soup = BeautifulSoup(html_doc, 'lxml')
print(soup.prettify())
news_tit = soup.findAll("a", {"class":"news_tit"})

for i in range(len(news_tit)):
  print(news_tit[i].get('title'))

# for link in soup.find_all('a'):
#   print(link.get('href'))
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    네이버 검색
#   </title>
#   <link href="https://ssl.pstatic.net/sstatic/search/css/2011/common.css" rel="stylesheet" type="text/css"/>
#   <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_32x32_240820.ico" rel="shortcut icon"/>
#   <style type="text/css">
# ...
